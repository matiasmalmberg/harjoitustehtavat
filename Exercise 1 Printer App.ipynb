# %%
creator = "Matias"

number1 = 10
number2 = 3

multiplication = number1 * number2
addition = number1 + number2
substraction = number1 -number2

print("Printer App")
print("This app is made by: Matias")

print("This app is made by: " + creator)

#print(number1) 

print("The value of the number1 is" ,number1)

print("The value of the number1 is" ,number2)

print(number1, "*" ,number2, "=" ,multiplication)

print(number1, "+" ,number2, "=" ,addition)

print(number1, "-", number2, "=", substraction)
# Out:
# Printer App
# This app is made by: Matias
# This app is made by: Matias
# The value of the number1 is 10
# The value of the number1 is 3
# 10 * 3 = 30
# 10 + 3 = 13
# 10 - 3 = 7
