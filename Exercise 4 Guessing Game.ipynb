# %%
secretname = "Matias"

guess = input("Guess the name ")

if guess == secretname:
    print("Congratulations!")
else:
    print("Try again")


secretname = "Matias"

guess = ""

while guess != secretname:
    guess = input("Guess the name ")

    if guess == secretname:
        print("Congratulations!")
# Out:
# Try again
# Congratulations!
